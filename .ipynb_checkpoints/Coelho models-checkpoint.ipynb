# %%
import numpy as np
from astropy import units as u
from astropy import constants as c
from random import choice
from astropy.table import Table
import spectral_cube
from astropy.io import fits
import pylab as plt
plt.style.use('dark_background')

# %%
# %run ../coelho_model_paa/compile_coelho_models.py

# %%
# %run aperture_plane_model.py
# Out:
# [0.0, -1.4027765763770978e-08, -4.0922660587975517e-08, 1.8167873769296383e-08, -9.114942818691123e-09, 1.28559420665469e-09]
# [0.0, -8.749505293123197e-08, -7.157477357462126e-08, -1.4369527636279404e-08, 1.0762663610378298e-08, -2.1769964027925496e-08]
# [0.0, -4.5131491186634065e-11, -7.740391796930119e-08, 1.3373538994802275e-08, -5.358540277451724e-09, 8.547210364163271e-09]
# [0.0, 2.0550582040333845e-08, -2.220628320352087e-09, 4.8444735229585256e-08, 6.986435425034003e-09, -1.4726177012333345e-08]
# [0.0, -1.0838022456019796e-08, 6.3943498473221e-08, 3.907242345604885e-08, -3.332197955545041e-08, 7.552038152766004e-09]

# %%
fh = fits.open('./s_coelho14_sed/t03400_g+0.5_m13p04_sed.fits')

# %%
sp = lower_dimensional_structures.OneDSpectrum.from_hdu(fh)

# %%
sp.quicklook()

# %%
# %run ../coelho_model_paa/coelho_specplot.py

# %%
models_table = table.Table.read('coelho14_model_paa.fits')
# Out:
# <Table length=3727>
#          3.6                    4.5           ...  K-paa_accr_1e-8
#        float64                float64         ...      float64
# ---------------------- ---------------------- ... ------------------
# 1.7727956444987645e-07  8.911647367270263e-08 ...  7.906731118085306
# 1.7756454656748614e-07  9.058007148839303e-08 ...  7.922373132717747
# 1.6858879750412503e-07  8.601684769313594e-08 ...  7.954831879649521
# 1.5733920438552083e-07  7.841738240461184e-08 ...  8.018289776423138
#  1.733438489747849e-07  8.959692632470967e-08 ...  7.915814918147027
# 1.5743963508681499e-07    8.5532285002118e-08 ...   8.07531336889073
#  1.613063483539495e-07  8.654930967555305e-08 ...  8.035457318187872
# 1.3505598929012374e-07  7.627373595199934e-08 ...  8.368126953824868
#   1.41010942442901e-07  6.145779567292062e-08 ...  8.106777121556709
# 1.6798325176351226e-07  8.490788407582901e-08 ...  8.003325050295885
#                    ...                    ... ...                ...
#  0.0001558840089688804 0.00032249198077738465 ...  5.552711312434198
# 0.00015538094887443933  0.0003214601344064285 ... 5.5611402557277145
# 0.00018448918825450528 0.00038187028422563617 ...  5.458748607460707
# 0.00018467097757936084 0.00038224194890395017 ... 5.4554410142376994
# 0.00018413812945561827 0.00038115747246745234 ...  5.467949042263812
# 0.00018147762506786147  0.0003756565715555542 ...  5.486692051299623
#  0.0001817213828841357 0.00037615858119038084 ...   5.48385118574924
# 0.00018117349673656363  0.0003750385503513938 ...   5.49438201841648
# 0.00021294830162072985  0.0004410299802115077 ...   5.41175644140427
#  0.0002090853405014336 0.00043305133800936203 ...  5.441975733366725

# %%
models_table[7]
# Out:
# <Row index=7>
#          3.6                    4.5                   5.8                    8.0                    H                      J                     K             afe     feh                        fn                       logg           paa          paa_plus_accr_1e-4 paa_plus_accr_1e-6   paa_plus_accr_1e-8         paac_h                paac_l           teff     z            mK                 mH                 mJ                m3.6               m4.5               m5.8              m8.0                H-K                 J-H               3.6-K             3.6-4.5             3.6-5.8            4.5-8.0            3.6-8.0             5.8-8.0             K-8.0             mag_paa             cont_m_paa         mag_cont_m_paa      mag_paac_l         mag_paac_h         paach-paacl         mag_paa-h         mag_paa-l         mag_paa-K          mag_paa-H           3.6-paa            8.0-paa          4.5-paa           5.8-paa          mag_paa_1e-4    3.6-paa_accr_1e-4 4.5-paa_accr_1e-4  5.8-paa_accr_1e-4  8.0-paa_accr_1e-4  J-paa_accr_1e-4    H-paa_accr_1e-4   K-paa_accr_1e-4      mag_paa_1e-6   3.6-paa_accr_1e-6  4.5-paa_accr_1e-6  5.8-paa_accr_1e-6 8.0-paa_accr_1e-6   J-paa_accr_1e-6   H-paa_accr_1e-6    K-paa_accr_1e-6     mag_paa_1e-8   3.6-paa_accr_1e-8  4.5-paa_accr_1e-8 5.8-paa_accr_1e-8  8.0-paa_accr_1e-8  J-paa_accr_1e-8   H-paa_accr_1e-8   K-paa_accr_1e-8
#        float64                float64               float64                float64               float64                float64               float64        float64 float64                   bytes43                   float64        float64             float64            float64              float64              float64               float64         float64 bytes21      float64            float64            float64            float64            float64            float64           float64             float64             float64            float64            float64             float64            float64            float64             float64            float64            float64              float64              float64           float64            float64             float64            float64           float64           float64            float64            float64            float64          float64           float64            float64            float64           float64            float64            float64           float64            float64           float64            float64           float64            float64            float64           float64            float64           float64            float64           float64           float64            float64           float64            float64           float64           float64           float64
# ---------------------- --------------------- ---------------------- --------------------- ---------------------- --------------------- --------------------- ------- ------- ------------------------------------------- ------- --------------------- ------------------ ------------------ --------------------- -------------------- ---------------------- ------- ------- ------------------ ------------------ ------------------ ------------------ ------------------ ----------------- ------------------ ------------------- ------------------- ------------------ ------------------ ------------------- ------------------ ------------------ ------------------- ------------------ ------------------ ---------------------- ----------------- ------------------ ------------------ ------------------- ----------------- ----------------- ------------------ ------------------ ------------------ ----------------- ---------------- ------------------ ------------------ ----------------- ------------------ ------------------ ----------------- ------------------ ----------------- ------------------ ----------------- ------------------ ------------------ ----------------- ------------------ ----------------- ------------------ ----------------- ----------------- ------------------ ----------------- ------------------ ------------------ ---------------- ----------------- -----------------
# 1.3505598929012374e-07 7.627373595199934e-08 2.9025989517286602e-08 8.976708314845752e-09 1.4107201593097933e-06 2.004769733093252e-06 6.280039533036069e-07     0.4    -1.3 s_coelho14_sed\t03000_g+0.0_m13p04_sed.fits     0.0 5.738730468389462e-07  8.291243340349872 0.1076042673303976 0.0013970538907925449 1.24540108888887e-06 1.7112975343766762e-06  3000.0  m13p04 15.505094055893721 14.626397818769485 14.244838757596943 17.173715378784348 17.794062452449563 18.84303241479844 20.117207215895966 -0.8786962371242364 -0.3815590611725419 1.6686213228906261 -0.620347073665215 -1.6693170360140925 -2.323144763446404 -2.943491837111619 -1.2741748010975265 -4.612113160002245 15.602960430831683 1.6530160897744038e-07 16.95430729791314 14.416686188443968 14.761726897246719 0.34504070880275073 21.50765118973037 21.36963490620927 21.804998053189173 21.453519558339476 1.5707549479526648 4.514246785064284 2.19110202161788 3.2400719839667573 -2.296549153686943 19.47026453247129 20.090611606136505 21.139581568485383 22.41375636958291 16.541387911283884 16.92294697245643 17.801643209580664 2.420426263093792 14.753289115690556 15.373636189355771 16.42260615170465 17.696780952802175 11.82441249450315 12.205971555675692 13.08466779279993 7.136967102068853 10.036748276715494 10.65709535038071 11.706065312729587 12.980240113827113 7.10787165552809 7.489430716700632 8.368126953824868

# %%
def value_keys(models_table):
    logg_values = []
    teff_values = []
    
    for value in models_table['logg']:
        if value not in logg_values:
            logg_values.append(value)
        
    for value in models_table['teff']:
        if value not in teff_values:
            teff_values.append(value)

    teff_dict = {"attribute": "effective temperature"}
    logg_dict = {"attribute": "surface gravity (log base 10)"}
    
    for value in teff_values:
        indices = []
        for ii in range(len(models_table)):
            if models_table['teff'][ii] == value:
                indices.append(ii)
        teff_dict[f'value is {value}'] = indices
    
    for value in logg_values:
        indices = []
        for ii in range(len(models_table)):
            if models_table['logg'][ii] == value:
                indices.append(ii)
        logg_dict[f'value is {value}'] = indices

    return teff_dict, logg_dict, teff_values, logg_values

# %%
teff_dict, logg_dict, teff_values, logg_values = value_keys(models_table)

# %%
def correct_keys(jj, models_table, tbl):
    keys = []
    
    init_min = np.argmin(np.abs(teff_values - tbl['teff'][jj]))
    teff_val = teff_values[init_min]
    init_min = np.argmin(np.abs(logg_values - tbl['logg'][jj]))
    logg_val = logg_values[init_min]
    
    keys_teff = teff_dict[f'value is {teff_val}']
    keys_logg = logg_dict[f'value is {logg_val}']
    
    for key in keys_teff:
        if key in keys_logg:
            keys.append(key)
            
    if len(keys) == 0:
        index = choice(keys_teff)
    else:
        index = choice(keys)
    
    return index

# %%
def closest_model(name, VVV=False):
    """"
    This assumes that we value teff being correct over logg.
    Unfortunately, trying to find the best fit from existing data requires us to use a strict poset.
    So one has to be prioritized over the other.
    """
    data_stars = np.loadtxt('./TRILEGAL_data/' + name, unpack=True)
    logTe = []
    logg = []
    index = 13
    if VVV:
        index += 2

    for ii in range(len(data_stars[0])):
        if data_stars[index, ii] >= 16:
            logTe.append(data_stars[5, ii])
            logg.append(data_stars[6, ii])

    tbl = Table({'logTe': logTe,
                 'logg': logg,
                 })

    tbl.add_column(col=(10**tbl['logTe']), name='teff')
    
    data_rows = []
    
    for jj in range(len(tbl)):
        index = correct_keys(jj=jj, models_table=models_table, tbl=tbl)
        
        temp_dict = {}
        for hh in range(len(models_table[index])):
            temp_dict[f'{models_table.colnames[hh]}'] = models_table[index][hh]
            
        data_rows.append(temp_dict)
        
    result = Table(rows=data_rows)
    
    return result

# %% [markdown]
# I'm going to run this with some fainter stars. Limiting mag will be 32, l=0.1, b=2.5, pix=50, area=0.00012531558641975312deg2.

# %%
data_m_1 = closest_model('data_m_1.dat')
data_v_1 = closest_model('data_v_1.dat', VVV=True)
data_m_1
# Out:
# <Table length=64906>
#          3.6                 3.6-4.5       ...   teff            z
#        float64               float64       ... float64         str21
# ---------------------- ------------------- ... ------- ---------------------
# 1.6798325176351226e-07 -0.7407949140903263 ...  3000.0                p00p04
#  1.528240033247138e-07 -0.7851129959295733 ...  3000.0                m01p04
